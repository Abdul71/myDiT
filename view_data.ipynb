# %%
from data import prepare_mnist_data, prepare_cifar10_data
import torchvision

# %%
trainloader, testloader, classes = prepare_cifar10_data(16, 4)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
trainloader

# %%
import matplotlib.pyplot as plt
import numpy as np

# functions to show an image


def imshow(img):
    img = img / 2 + 0.5     # unnormalize
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.show()


# get some random training images
dataiter = iter(trainloader)
images, labels = next(dataiter)

# show images
imshow(torchvision.utils.make_grid(images))
# print labels
print(' '.join(f'{classes[labels[j]]:5s}' for j in range(16)))
# Out:
# car   horse dog   car   horse plane frog  bird  frog  plane plane plane deer  deer  horse horse

# %%
images.shape
# Out:
# torch.Size([16, 3, 32, 32])
